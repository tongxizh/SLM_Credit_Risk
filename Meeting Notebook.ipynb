# %% [markdown]
# # 1. Missing First Name, Last Name
# - **First Name**: to infer gender
#
# - **Last Name**: to infer race
#
# | Missing First Name | Missing Last Name |
# |--------------------|-------------------|
# |        8465        |       8446        |

# %% [markdown]
# # 2. Duplicates
#
# **First party data has 19,854 rows of duplicated:** if a ZIPCode with fewer customer directs mails, duplicates can potentially increase the percent of relative race.
#
# ![1.PNG](attachment:cafa073e-fdd1-46bd-a0d3-94e978580110.PNG)

# %% [markdown]
# # 3. PO Box Address
#
# **Total number of addresses containing 'PO BOX' is 24,319, The percent is 1.23%.**
#
# **For some of PO BOXes are  post offices, no zipcode or census level demongraphic infomation**.
#
# ![tx pobox.PNG](attachment:a3057015-e0ba-449c-9c60-8ed369e2455f.PNG)
#
# ![TX 77410.PNG](attachment:7eddf396-4807-4f60-9051-4b9ee5a6cd08.PNG)

# %% [markdown]
# # 4. States Abbreviations not Valid

# %% [markdown]
# | ST_CD | Count |
# |-------|-------|
# | AA    | 27    |
# | AE    | 57    |
# | AP    | 22    |
# | FC    | 1     |
# | FM    | 1     |
# | MH    | 3     |
# | PW    | 7     |
# | ZZ    | 1     |
# | Total | 119   |

# %% [markdown]
# **Five unincorporated territories.**
#
# **PR: 379, GU: 88, VI: 32, MP: 18, AS: 12**

# %% [markdown]
# The ZIP code for American Samoa is 96799. This unique five-digit code is used for all mail delivery in the territory (USPS).
# ![as.PNG](attachment:4195e6a8-8441-489b-ad8c-15d495dde70d.PNG)

# %% [markdown]
# # 5. Street Address has no numbers
#
# Only look at the pattern like
# ```python
# re.search(r'[A-Za-z]*\d+[A-Za-z]*'
#
#
# ```

# %% [markdown]
# - **Number of addresses without street numbers: 1,798, about 0.1%**
#
# ![no street no.PNG](attachment:d18d9e3d-980a-4c71-a556-6f6a4a1f6fd0.PNG)
#
# - **Not check the addresses without street abbreviations, too many cases, difficult without the usage of a charged API.**

# %%
# 6. Contains some zip codes that do not conform to the established range.

For exmaple: 


- **Texas:** between 73301 and 88595, total 119 DM ZIP-Codes in Texas out of this range.


![tx_out_of_range.PNG](attachment:4a155611-04ca-47df-b1bd-741d5787930b.PNG)

- **California:** between 90001 and 96162, total 42 DM ZIP-Codes in California out of this range.

![ca_out_of_range_example.PNG](attachment:c2a04b3f-a8bf-4821-9063-17d0fa852a4b.PNG)

- **Seems like ZIP-Code 20171 is a special case, total number of DMs to 20171, state not in Virginia is **603**.**

- **Approximately, less than 1,000 ZIP5 (based on DM state count distritution) that do not confrom to the established range.**

# %% [markdown]
# # 7. Others
#
# Some ZIPs don't have demographic information (population) for compliance purpose when merging with US cencus data.
#
# For example: 73301.
#
# - **9 Direct Mails to 73301.**
#
# ![73301.PNG](attachment:f65b6e27-9c4c-4aa2-a094-7dcf52add001.PNG)

# %% [markdown]
# ![image.png](attachment:c8c673d5-ffbd-41bc-b807-402adf2b24be.png)
