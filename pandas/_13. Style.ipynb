# %%
import numpy as np
import pandas as pd 
print(pd.__version__)
# Out:
# 2.0.2

# %% [markdown]
# # Style Overview
#
# Pandas' Style functionality allows for highlighting the logic and features of the data, making it more visually striking and clear.
#
# For example, representing a currency value of 25.06 as "$25.06" provides additional information about the currency, and using styles can enhance the presentation of the data. Similarly, representing 0.12 as "12%" makes the data more intuitive, clear, and simple to understand.
#
# The fundamental concept of styling in Pandas is that it allows users to modify the display format of data without affecting the underlying data itself. In other words, the data type remains unchanged, allowing for the use of various mathematical, date, and string functions provided by Pandas for data processing.
#
# Pandas' Style functionality also includes advanced styling options, such as adding colors and bar charts as visual elements.

# %% [markdown]
# ## Main features of Pandas' Style functionality
# * Value formatting: Formatting numerical values with features such as thousands separators, decimal places, currency symbols, date formats, percentages, etc.
#
# * Highlighting data: Applying styles to specific rows, columns, or values (e.g., minimum and maximum values) using features like font size, colors, backgrounds, etc.
#
# * Visualizing data relationships: Using color shades or gradients to represent variations in data magnitude.
#
# * Miniature bar charts: Representing proportions or percentages within a small grid cell using color scales.
# * Trend representation: Similar to sparklines in Excel, representing trends or changes in data over time with miniature trend charts.
#
# The key difference between styles and visualizations is that visualizations generally focus on presenting data without specific details, while styles decorate the data while retaining its specific content to enhance readability. However, there can be cases where these two approaches overlap and are used together.

# %% [markdown]
# ## Style Object
# The Style object in Pandas DataFrame is used to declare the styling of data. Styling is achieved using CSS (Cascading Style Sheets).
#
# All the styling functionalities are available under the `df.style object`. It allows us to display all the data without any specific styling in the notebook.

# %% [markdown]
# ## Style Exporting
# The DataFrame with styling can be exported using `df.style.to_excel()` method. The exported Excel file will retain the styling applied to the DataFrame.

# %%
df = pd.DataFrame({'Name':['James', 'Messi', 'Durant', 'Irvine', 'Harden'],
                  'Team' : list('ABCDE'),
                  'Q1': np.random.randint(60, 80, 5),
                'Q2': np.random.randint(70, 90, 5),
                   'Q3': np.random.randint(60, 70, 5),
                   'Q4': np.random.randint(30, 80, 5)
})
df
# Out:
#      Name Team  Q1  Q2  Q3  Q4
# 0   James    A  69  73  69  60
# 1   Messi    B  77  88  61  52
# 2  Durant    C  70  72  67  34
# 3  Irvine    D  72  71  68  34
# 4  Harden    E  70  79  61  73

# %% [markdown]
# # Build-in style function
# * `highlight_max()`: Highlight the maximum value in each column.
# * `highlight_min()`: Highlight the minimum value in each column.
# * `highlight_greater()`: Highlight cells greater than a specified value.
# * `highlight_less()`: Highlight cells less than a specified value.
# * `highlight_between()`: Highlight cells within a specified range.
# * `background_gradient()`: Apply a gradient background color to cells based on their values.
# * `bar()`: Draw horizontal bar charts in cells.
# * `color_negative()`: Apply a specific color to cells with negative values.
# * `set_precision()`: Set the display precision for floating-point numbers

# %% [markdown]
# ## `highlight_null`

# %%
df.iloc[1,1] = np.NaN # Revise a null value
df.head().style.highlight_null() # Default color red
# Out:
# <style type="text/css">
# #T_91e05_row1_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_91e05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91e05_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_91e05_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_91e05_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_91e05_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_91e05_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_91e05_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91e05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91e05_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_91e05_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_91e05_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_91e05_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_91e05_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_91e05_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_91e05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91e05_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_91e05_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_91e05_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_91e05_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_91e05_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_91e05_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_91e05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91e05_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_91e05_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_91e05_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_91e05_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_91e05_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_91e05_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_91e05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91e05_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_91e05_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_91e05_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_91e05_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_91e05_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_91e05_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_91e05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91e05_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_91e05_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_91e05_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_91e05_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_91e05_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_91e05_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the new color 
df.style.highlight_null(color = 'blue')
# Out:
# <style type="text/css">
# #T_5dccb_row1_col1 {
#   background-color: blue;
# }
# </style>
# <table id="T_5dccb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dccb_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5dccb_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_5dccb_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_5dccb_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_5dccb_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_5dccb_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dccb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dccb_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_5dccb_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_5dccb_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_5dccb_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_5dccb_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_5dccb_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_5dccb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dccb_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_5dccb_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_5dccb_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_5dccb_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_5dccb_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_5dccb_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_5dccb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dccb_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_5dccb_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_5dccb_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_5dccb_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_5dccb_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_5dccb_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_5dccb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dccb_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_5dccb_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_5dccb_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_5dccb_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_5dccb_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_5dccb_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_5dccb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5dccb_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_5dccb_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_5dccb_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_5dccb_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_5dccb_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_5dccb_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.highlight_null(color = '#ccc')
# Out:
# <style type="text/css">
# #T_faf7d_row1_col1 {
#   background-color: #ccc;
# }
# </style>
# <table id="T_faf7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faf7d_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_faf7d_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_faf7d_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_faf7d_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_faf7d_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_faf7d_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faf7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faf7d_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_faf7d_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_faf7d_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_faf7d_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_faf7d_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_faf7d_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_faf7d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_faf7d_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_faf7d_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_faf7d_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_faf7d_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_faf7d_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_faf7d_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_faf7d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_faf7d_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_faf7d_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_faf7d_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_faf7d_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_faf7d_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_faf7d_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_faf7d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_faf7d_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_faf7d_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_faf7d_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_faf7d_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_faf7d_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_faf7d_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_faf7d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_faf7d_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_faf7d_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_faf7d_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_faf7d_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_faf7d_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_faf7d_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlight `max` and `min` values

# %%
df.iloc[:, 2:6].style.highlight_max()
# Out:
# <style type="text/css">
# #T_11555_row0_col2, #T_11555_row1_col0, #T_11555_row1_col1, #T_11555_row4_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_11555">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11555_level0_col0" class="col_heading level0 col0" >Q1</th>
#       <th id="T_11555_level0_col1" class="col_heading level0 col1" >Q2</th>
#       <th id="T_11555_level0_col2" class="col_heading level0 col2" >Q3</th>
#       <th id="T_11555_level0_col3" class="col_heading level0 col3" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11555_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11555_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_11555_row0_col1" class="data row0 col1" >73</td>
#       <td id="T_11555_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_11555_row0_col3" class="data row0 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_11555_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11555_row1_col0" class="data row1 col0" >77</td>
#       <td id="T_11555_row1_col1" class="data row1 col1" >88</td>
#       <td id="T_11555_row1_col2" class="data row1 col2" >61</td>
#       <td id="T_11555_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_11555_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11555_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_11555_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_11555_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_11555_row2_col3" class="data row2 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_11555_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11555_row3_col0" class="data row3 col0" >72</td>
#       <td id="T_11555_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_11555_row3_col2" class="data row3 col2" >68</td>
#       <td id="T_11555_row3_col3" class="data row3 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_11555_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11555_row4_col0" class="data row4 col0" >70</td>
#       <td id="T_11555_row4_col1" class="data row4 col1" >79</td>
#       <td id="T_11555_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_11555_row4_col3" class="data row4 col3" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.iloc[:, 2:6].style.highlight_min()
# Out:
# <style type="text/css">
# #T_0cac9_row0_col0, #T_0cac9_row1_col2, #T_0cac9_row2_col3, #T_0cac9_row3_col1, #T_0cac9_row3_col3, #T_0cac9_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0cac9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cac9_level0_col0" class="col_heading level0 col0" >Q1</th>
#       <th id="T_0cac9_level0_col1" class="col_heading level0 col1" >Q2</th>
#       <th id="T_0cac9_level0_col2" class="col_heading level0 col2" >Q3</th>
#       <th id="T_0cac9_level0_col3" class="col_heading level0 col3" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cac9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cac9_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_0cac9_row0_col1" class="data row0 col1" >73</td>
#       <td id="T_0cac9_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_0cac9_row0_col3" class="data row0 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0cac9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cac9_row1_col0" class="data row1 col0" >77</td>
#       <td id="T_0cac9_row1_col1" class="data row1 col1" >88</td>
#       <td id="T_0cac9_row1_col2" class="data row1 col2" >61</td>
#       <td id="T_0cac9_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_0cac9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cac9_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_0cac9_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_0cac9_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_0cac9_row2_col3" class="data row2 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0cac9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cac9_row3_col0" class="data row3 col0" >72</td>
#       <td id="T_0cac9_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_0cac9_row3_col2" class="data row3 col2" >68</td>
#       <td id="T_0cac9_row3_col3" class="data row3 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0cac9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cac9_row4_col0" class="data row4 col0" >70</td>
#       <td id="T_0cac9_row4_col1" class="data row4 col1" >79</td>
#       <td id="T_0cac9_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_0cac9_row4_col3" class="data row4 col3" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Max and min simultaneously 
df.iloc[:, 2:6].style.highlight_min().highlight_max(color = 'lime')
# Out:
# <style type="text/css">
# #T_34cf8_row0_col0, #T_34cf8_row1_col2, #T_34cf8_row2_col3, #T_34cf8_row3_col1, #T_34cf8_row3_col3, #T_34cf8_row4_col2 {
#   background-color: yellow;
# }
# #T_34cf8_row0_col2, #T_34cf8_row1_col0, #T_34cf8_row1_col1, #T_34cf8_row4_col3 {
#   background-color: lime;
# }
# </style>
# <table id="T_34cf8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34cf8_level0_col0" class="col_heading level0 col0" >Q1</th>
#       <th id="T_34cf8_level0_col1" class="col_heading level0 col1" >Q2</th>
#       <th id="T_34cf8_level0_col2" class="col_heading level0 col2" >Q3</th>
#       <th id="T_34cf8_level0_col3" class="col_heading level0 col3" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34cf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34cf8_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_34cf8_row0_col1" class="data row0 col1" >73</td>
#       <td id="T_34cf8_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_34cf8_row0_col3" class="data row0 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_34cf8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34cf8_row1_col0" class="data row1 col0" >77</td>
#       <td id="T_34cf8_row1_col1" class="data row1 col1" >88</td>
#       <td id="T_34cf8_row1_col2" class="data row1 col2" >61</td>
#       <td id="T_34cf8_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_34cf8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34cf8_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_34cf8_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_34cf8_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_34cf8_row2_col3" class="data row2 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_34cf8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34cf8_row3_col0" class="data row3 col0" >72</td>
#       <td id="T_34cf8_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_34cf8_row3_col2" class="data row3 col2" >68</td>
#       <td id="T_34cf8_row3_col3" class="data row3 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_34cf8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34cf8_row4_col0" class="data row4 col0" >70</td>
#       <td id="T_34cf8_row4_col1" class="data row4 col1" >79</td>
#       <td id="T_34cf8_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_34cf8_row4_col3" class="data row4 col3" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.iloc[:, 2:6].style.highlight_min(axis = 1).highlight_max(color = 'lime', axis = 1)
# Out:
# <style type="text/css">
# #T_1a621_row0_col1, #T_1a621_row1_col1, #T_1a621_row2_col1, #T_1a621_row3_col0, #T_1a621_row4_col1 {
#   background-color: lime;
# }
# #T_1a621_row0_col3, #T_1a621_row1_col3, #T_1a621_row2_col3, #T_1a621_row3_col3, #T_1a621_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1a621">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a621_level0_col0" class="col_heading level0 col0" >Q1</th>
#       <th id="T_1a621_level0_col1" class="col_heading level0 col1" >Q2</th>
#       <th id="T_1a621_level0_col2" class="col_heading level0 col2" >Q3</th>
#       <th id="T_1a621_level0_col3" class="col_heading level0 col3" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a621_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a621_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_1a621_row0_col1" class="data row0 col1" >73</td>
#       <td id="T_1a621_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_1a621_row0_col3" class="data row0 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_1a621_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a621_row1_col0" class="data row1 col0" >77</td>
#       <td id="T_1a621_row1_col1" class="data row1 col1" >88</td>
#       <td id="T_1a621_row1_col2" class="data row1 col2" >61</td>
#       <td id="T_1a621_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_1a621_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a621_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_1a621_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_1a621_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_1a621_row2_col3" class="data row2 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1a621_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a621_row3_col0" class="data row3 col0" >72</td>
#       <td id="T_1a621_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_1a621_row3_col2" class="data row3 col2" >68</td>
#       <td id="T_1a621_row3_col3" class="data row3 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1a621_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a621_row4_col0" class="data row4 col0" >70</td>
#       <td id="T_1a621_row4_col1" class="data row4 col1" >79</td>
#       <td id="T_1a621_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_1a621_row4_col3" class="data row4 col3" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# subset
df.style.highlight_min(subset = ['Q1', 'Q2'])
# Out:
# <style type="text/css">
# #T_159d0_row0_col2, #T_159d0_row3_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_159d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_159d0_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_159d0_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_159d0_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_159d0_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_159d0_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_159d0_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_159d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_159d0_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_159d0_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_159d0_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_159d0_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_159d0_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_159d0_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_159d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_159d0_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_159d0_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_159d0_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_159d0_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_159d0_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_159d0_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_159d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_159d0_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_159d0_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_159d0_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_159d0_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_159d0_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_159d0_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_159d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_159d0_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_159d0_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_159d0_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_159d0_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_159d0_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_159d0_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_159d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_159d0_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_159d0_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_159d0_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_159d0_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_159d0_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_159d0_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `background_gradient`
# To apply a gradient color scheme based on the magnitude of the values in a DataFrame, we can use the `background_gradient()` method of the Styler object in Pandas. This method allows you to specify the color map from the `Matplotlib colormap` for the gradient.

# %%
df.style.background_gradient(axis = 0)
# Out:
# <style type="text/css">
# #T_0754b_row0_col2, #T_0754b_row1_col4, #T_0754b_row2_col5, #T_0754b_row3_col3, #T_0754b_row3_col5, #T_0754b_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0754b_row0_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_0754b_row0_col4, #T_0754b_row1_col2, #T_0754b_row1_col3, #T_0754b_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0754b_row0_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_0754b_row1_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_0754b_row2_col2, #T_0754b_row4_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_0754b_row2_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_0754b_row2_col4 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_0754b_row3_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_0754b_row3_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_0754b_row4_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0754b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0754b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0754b_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_0754b_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_0754b_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_0754b_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_0754b_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0754b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0754b_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_0754b_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_0754b_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_0754b_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_0754b_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_0754b_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0754b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0754b_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_0754b_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_0754b_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_0754b_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_0754b_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_0754b_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_0754b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0754b_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_0754b_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_0754b_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_0754b_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_0754b_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_0754b_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0754b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0754b_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_0754b_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_0754b_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_0754b_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_0754b_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_0754b_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0754b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0754b_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_0754b_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_0754b_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_0754b_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_0754b_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_0754b_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(low = 0.6, high = 0)
# Out:
# <style type="text/css">
# #T_96c86_row0_col2, #T_96c86_row1_col4, #T_96c86_row4_col4 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_96c86_row0_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_96c86_row0_col4, #T_96c86_row1_col2, #T_96c86_row1_col3, #T_96c86_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_96c86_row0_col5 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_96c86_row1_col5 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_96c86_row2_col2, #T_96c86_row4_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_96c86_row2_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_96c86_row2_col4 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_96c86_row2_col5, #T_96c86_row3_col3, #T_96c86_row3_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_96c86_row3_col2 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_96c86_row3_col4 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_96c86_row4_col3 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96c86_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_96c86_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_96c86_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_96c86_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_96c86_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_96c86_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96c86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96c86_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_96c86_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_96c86_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_96c86_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_96c86_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_96c86_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96c86_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_96c86_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_96c86_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_96c86_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_96c86_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_96c86_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96c86_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_96c86_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_96c86_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_96c86_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_96c86_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_96c86_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96c86_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_96c86_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_96c86_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_96c86_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_96c86_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_96c86_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96c86_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_96c86_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_96c86_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_96c86_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_96c86_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_96c86_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `text_color_threshold` parameter in the `Styler.background_gradient()` method allows you to specify a threshold value for the text color, When the background color of a cell crosses this threshold, the text color will automatically switch between black and white to ensure optimal visibility.
#
# In below example, if the background color of a cell is darker than 0.5, the text color will be switched to white for better visibility. If the background color is lighter than 0.5, the text color will be black.

# %%
df.style.background_gradient(text_color_threshold = 0.5)
# Out:
# <style type="text/css">
# #T_7e660_row0_col2, #T_7e660_row1_col4, #T_7e660_row2_col5, #T_7e660_row3_col3, #T_7e660_row3_col5, #T_7e660_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7e660_row0_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_7e660_row0_col4, #T_7e660_row1_col2, #T_7e660_row1_col3, #T_7e660_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7e660_row0_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_7e660_row1_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_7e660_row2_col2, #T_7e660_row4_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_7e660_row2_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_7e660_row2_col4 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_7e660_row3_col2 {
#   background-color: #a5bddb;
#   color: #f1f1f1;
# }
# #T_7e660_row3_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_7e660_row4_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e660">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e660_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7e660_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_7e660_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_7e660_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_7e660_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_7e660_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e660_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e660_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_7e660_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_7e660_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_7e660_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_7e660_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_7e660_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_7e660_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e660_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_7e660_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_7e660_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_7e660_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_7e660_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_7e660_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_7e660_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e660_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_7e660_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_7e660_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_7e660_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_7e660_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_7e660_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7e660_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e660_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_7e660_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_7e660_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_7e660_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_7e660_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_7e660_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7e660_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e660_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_7e660_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_7e660_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_7e660_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_7e660_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_7e660_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `vmin` and `vmax` parameters in the `Styler.background_gradient()` method allow you to specify the minimum and maximum values for the color mapping. The values in the DataFrame will be mapped to the corresponding colors based on this range.

# %%
df.style.background_gradient(vmin = 60, vmax = 100)
# Out:
# <style type="text/css">
# #T_469d6_row0_col2, #T_469d6_row0_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_469d6_row0_col3, #T_469d6_row4_col5 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_469d6_row0_col5, #T_469d6_row1_col5, #T_469d6_row2_col5, #T_469d6_row3_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_469d6_row1_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_469d6_row1_col3 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_469d6_row1_col4, #T_469d6_row4_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_469d6_row2_col2, #T_469d6_row4_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_469d6_row2_col3, #T_469d6_row3_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_469d6_row2_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_469d6_row3_col3 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_469d6_row3_col4 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_469d6_row4_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_469d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_469d6_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_469d6_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_469d6_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_469d6_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_469d6_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_469d6_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_469d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_469d6_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_469d6_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_469d6_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_469d6_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_469d6_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_469d6_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_469d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_469d6_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_469d6_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_469d6_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_469d6_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_469d6_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_469d6_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_469d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_469d6_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_469d6_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_469d6_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_469d6_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_469d6_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_469d6_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_469d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_469d6_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_469d6_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_469d6_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_469d6_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_469d6_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_469d6_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_469d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_469d6_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_469d6_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_469d6_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_469d6_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_469d6_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_469d6_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# A general case
# Chained method using styles
(df.style.background_gradient(subset=['Q1'], cmap='spring')  # Specify the colormap
.background_gradient(subset=['Q2'], vmin=60, vmax=100)  # Specify the applied value range
.background_gradient(subset=['Q3'], low=0.6, high=0) # Gradient percentage range
.background_gradient(subset=['Q4'], text_color_threshold=0.9)  # Text color threshold
)
# Out:
# <style type="text/css">
# #T_c53fb_row0_col2 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_c53fb_row0_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_c53fb_row0_col4, #T_c53fb_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c53fb_row0_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_c53fb_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_c53fb_row1_col3 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_c53fb_row1_col4, #T_c53fb_row4_col4 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_c53fb_row1_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_c53fb_row2_col2, #T_c53fb_row4_col2 {
#   background-color: #ff20df;
#   color: #f1f1f1;
# }
# #T_c53fb_row2_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_c53fb_row2_col4 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_c53fb_row2_col5, #T_c53fb_row3_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c53fb_row3_col2 {
#   background-color: #ff609f;
#   color: #f1f1f1;
# }
# #T_c53fb_row3_col3 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_c53fb_row3_col4 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_c53fb_row4_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c53fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c53fb_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_c53fb_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_c53fb_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_c53fb_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_c53fb_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_c53fb_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c53fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c53fb_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_c53fb_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_c53fb_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_c53fb_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_c53fb_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_c53fb_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_c53fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c53fb_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_c53fb_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_c53fb_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_c53fb_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_c53fb_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_c53fb_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_c53fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c53fb_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_c53fb_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_c53fb_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_c53fb_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_c53fb_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_c53fb_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c53fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c53fb_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_c53fb_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_c53fb_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_c53fb_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_c53fb_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_c53fb_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c53fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c53fb_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_c53fb_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_c53fb_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_c53fb_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_c53fb_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_c53fb_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Bar Chart
# A bar chart represents the magnitude of a value in a table using horizontal bars.

# %%
df.style.bar()
# Out:
# <style type="text/css">
# #T_48a5f_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_48a5f_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_48a5f_row0_col4, #T_48a5f_row1_col2, #T_48a5f_row1_col3, #T_48a5f_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_48a5f_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.2%, transparent 82.2%);
# }
# #T_48a5f_row1_col4, #T_48a5f_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.4%, transparent 88.4%);
# }
# #T_48a5f_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.2%, transparent 71.2%);
# }
# #T_48a5f_row2_col2, #T_48a5f_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_48a5f_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_48a5f_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.1%, transparent 97.1%);
# }
# #T_48a5f_row2_col5, #T_48a5f_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.6%, transparent 46.6%);
# }
# #T_48a5f_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.5%, transparent 93.5%);
# }
# #T_48a5f_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_48a5f_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_48a5f_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.8%, transparent 89.8%);
# }
# </style>
# <table id="T_48a5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48a5f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_48a5f_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_48a5f_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_48a5f_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_48a5f_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_48a5f_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48a5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48a5f_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_48a5f_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_48a5f_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_48a5f_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_48a5f_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_48a5f_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_48a5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48a5f_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_48a5f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_48a5f_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_48a5f_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_48a5f_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_48a5f_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_48a5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48a5f_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_48a5f_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_48a5f_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_48a5f_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_48a5f_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_48a5f_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_48a5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48a5f_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_48a5f_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_48a5f_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_48a5f_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_48a5f_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_48a5f_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_48a5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48a5f_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_48a5f_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_48a5f_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_48a5f_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_48a5f_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_48a5f_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the subset
df.style.bar(subset = ['Q1', 'Q2'])
# Out:
# <style type="text/css">
# #T_6576e_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_6576e_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_6576e_row1_col2, #T_6576e_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_6576e_row2_col2, #T_6576e_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_6576e_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_6576e_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.5%, transparent 93.5%);
# }
# #T_6576e_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_6576e_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.8%, transparent 89.8%);
# }
# </style>
# <table id="T_6576e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6576e_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_6576e_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_6576e_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_6576e_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_6576e_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_6576e_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6576e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6576e_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_6576e_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_6576e_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_6576e_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_6576e_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_6576e_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_6576e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6576e_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_6576e_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_6576e_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_6576e_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_6576e_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_6576e_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_6576e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6576e_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_6576e_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_6576e_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_6576e_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_6576e_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_6576e_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_6576e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6576e_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_6576e_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_6576e_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_6576e_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_6576e_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_6576e_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_6576e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6576e_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_6576e_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_6576e_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_6576e_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_6576e_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_6576e_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the color
df.style.bar(color = 'green')
# Out:
# <style type="text/css">
# #T_edd52_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 89.6%, transparent 89.6%);
# }
# #T_edd52_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 83.0%, transparent 83.0%);
# }
# #T_edd52_row0_col4, #T_edd52_row1_col2, #T_edd52_row1_col3, #T_edd52_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_edd52_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 82.2%, transparent 82.2%);
# }
# #T_edd52_row1_col4, #T_edd52_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, green 88.4%, transparent 88.4%);
# }
# #T_edd52_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 71.2%, transparent 71.2%);
# }
# #T_edd52_row2_col2, #T_edd52_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 90.9%, transparent 90.9%);
# }
# #T_edd52_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 81.8%, transparent 81.8%);
# }
# #T_edd52_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, green 97.1%, transparent 97.1%);
# }
# #T_edd52_row2_col5, #T_edd52_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 46.6%, transparent 46.6%);
# }
# #T_edd52_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 93.5%, transparent 93.5%);
# }
# #T_edd52_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 80.7%, transparent 80.7%);
# }
# #T_edd52_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, green 98.6%, transparent 98.6%);
# }
# #T_edd52_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 89.8%, transparent 89.8%);
# }
# </style>
# <table id="T_edd52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edd52_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_edd52_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_edd52_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_edd52_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_edd52_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_edd52_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edd52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edd52_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_edd52_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_edd52_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_edd52_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_edd52_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_edd52_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_edd52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edd52_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_edd52_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_edd52_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_edd52_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_edd52_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_edd52_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_edd52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edd52_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_edd52_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_edd52_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_edd52_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_edd52_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_edd52_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_edd52_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edd52_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_edd52_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_edd52_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_edd52_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_edd52_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_edd52_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_edd52_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edd52_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_edd52_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_edd52_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_edd52_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_edd52_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_edd52_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Horizongtal calculation
df.style.bar(axis = 1)
# Out:
# <style type="text/css">
# #T_1d019_row0_col2, #T_1d019_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.5%, transparent 94.5%);
# }
# #T_1d019_row0_col3, #T_1d019_row1_col3, #T_1d019_row2_col3, #T_1d019_row3_col2, #T_1d019_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_1d019_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.2%, transparent 82.2%);
# }
# #T_1d019_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.5%, transparent 87.5%);
# }
# #T_1d019_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.3%, transparent 69.3%);
# }
# #T_1d019_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.1%, transparent 59.1%);
# }
# #T_1d019_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.2%, transparent 97.2%);
# }
# #T_1d019_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.1%, transparent 93.1%);
# }
# #T_1d019_row2_col5, #T_1d019_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.2%, transparent 47.2%);
# }
# #T_1d019_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_1d019_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.4%, transparent 94.4%);
# }
# #T_1d019_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.6%, transparent 88.6%);
# }
# #T_1d019_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.2%, transparent 77.2%);
# }
# #T_1d019_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.4%, transparent 92.4%);
# }
# </style>
# <table id="T_1d019">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d019_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_1d019_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_1d019_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_1d019_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_1d019_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_1d019_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d019_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d019_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_1d019_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_1d019_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_1d019_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_1d019_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_1d019_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_1d019_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d019_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_1d019_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_1d019_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_1d019_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_1d019_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_1d019_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_1d019_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d019_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_1d019_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_1d019_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_1d019_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_1d019_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_1d019_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1d019_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d019_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_1d019_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_1d019_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_1d019_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_1d019_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_1d019_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1d019_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1d019_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_1d019_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_1d019_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_1d019_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_1d019_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_1d019_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set the width of the bars to 80 pixels, you can use:
df.style.bar(width = 80)
# Out:
# <style type="text/css">
# #T_c1479_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.7%, transparent 71.7%);
# }
# #T_c1479_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.4%, transparent 66.4%);
# }
# #T_c1479_row0_col4, #T_c1479_row1_col2, #T_c1479_row1_col3, #T_c1479_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.0%, transparent 80.0%);
# }
# #T_c1479_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.8%, transparent 65.8%);
# }
# #T_c1479_row1_col4, #T_c1479_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.7%, transparent 70.7%);
# }
# #T_c1479_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.0%, transparent 57.0%);
# }
# #T_c1479_row2_col2, #T_c1479_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.7%, transparent 72.7%);
# }
# #T_c1479_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.5%, transparent 65.5%);
# }
# #T_c1479_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.7%, transparent 77.7%);
# }
# #T_c1479_row2_col5, #T_c1479_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.3%, transparent 37.3%);
# }
# #T_c1479_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.8%, transparent 74.8%);
# }
# #T_c1479_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.5%, transparent 64.5%);
# }
# #T_c1479_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.8%, transparent 78.8%);
# }
# #T_c1479_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.8%, transparent 71.8%);
# }
# </style>
# <table id="T_c1479">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1479_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_c1479_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_c1479_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_c1479_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_c1479_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_c1479_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1479_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1479_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_c1479_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_c1479_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_c1479_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_c1479_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_c1479_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_c1479_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1479_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_c1479_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_c1479_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_c1479_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_c1479_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_c1479_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_c1479_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1479_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_c1479_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_c1479_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_c1479_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_c1479_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_c1479_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c1479_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1479_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_c1479_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_c1479_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_c1479_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_c1479_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_c1479_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c1479_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1479_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_c1479_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_c1479_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_c1479_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_c1479_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_c1479_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.bar(align = 'mid')
# Out:
# <style type="text/css">
# #T_7a9da_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_7a9da_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_7a9da_row0_col4, #T_7a9da_row1_col2, #T_7a9da_row1_col3, #T_7a9da_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_7a9da_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.2%, transparent 82.2%);
# }
# #T_7a9da_row1_col4, #T_7a9da_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.4%, transparent 88.4%);
# }
# #T_7a9da_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.2%, transparent 71.2%);
# }
# #T_7a9da_row2_col2, #T_7a9da_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_7a9da_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_7a9da_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.1%, transparent 97.1%);
# }
# #T_7a9da_row2_col5, #T_7a9da_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.6%, transparent 46.6%);
# }
# #T_7a9da_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.5%, transparent 93.5%);
# }
# #T_7a9da_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_7a9da_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_7a9da_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.8%, transparent 89.8%);
# }
# </style>
# <table id="T_7a9da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a9da_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7a9da_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_7a9da_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_7a9da_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_7a9da_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_7a9da_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a9da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a9da_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_7a9da_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_7a9da_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_7a9da_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_7a9da_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_7a9da_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_7a9da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a9da_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_7a9da_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_7a9da_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_7a9da_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_7a9da_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_7a9da_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_7a9da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a9da_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_7a9da_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_7a9da_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_7a9da_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_7a9da_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_7a9da_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7a9da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a9da_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_7a9da_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_7a9da_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_7a9da_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_7a9da_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_7a9da_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7a9da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a9da_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_7a9da_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_7a9da_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_7a9da_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_7a9da_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_7a9da_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 'left': The bars start from the minimum value.
#'zero': The bars are centered around zero (0) value.
# 'mid': The bars are centered around the midpoint 
#  between the minimum and maximum values. Negative (positive) values will have zero (0) on the right (left) side.

df.style.bar(align = 'zero')
# Out:
# <style type="text/css">
# #T_adfd1_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 94.8%, transparent 94.8%);
# }
# #T_adfd1_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 91.5%, transparent 91.5%);
# }
# #T_adfd1_row0_col4, #T_adfd1_row1_col2, #T_adfd1_row1_col3, #T_adfd1_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_adfd1_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 91.1%, transparent 91.1%);
# }
# #T_adfd1_row1_col4, #T_adfd1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 94.2%, transparent 94.2%);
# }
# #T_adfd1_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 85.6%, transparent 85.6%);
# }
# #T_adfd1_row2_col2, #T_adfd1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 95.5%, transparent 95.5%);
# }
# #T_adfd1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_adfd1_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_adfd1_row2_col5, #T_adfd1_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 73.3%, transparent 73.3%);
# }
# #T_adfd1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 96.8%, transparent 96.8%);
# }
# #T_adfd1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 90.3%, transparent 90.3%);
# }
# #T_adfd1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 99.3%, transparent 99.3%);
# }
# #T_adfd1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 94.9%, transparent 94.9%);
# }
# </style>
# <table id="T_adfd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adfd1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_adfd1_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_adfd1_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_adfd1_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_adfd1_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_adfd1_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adfd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_adfd1_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_adfd1_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_adfd1_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_adfd1_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_adfd1_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_adfd1_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_adfd1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_adfd1_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_adfd1_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_adfd1_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_adfd1_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_adfd1_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_adfd1_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_adfd1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_adfd1_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_adfd1_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_adfd1_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_adfd1_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_adfd1_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_adfd1_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_adfd1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_adfd1_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_adfd1_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_adfd1_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_adfd1_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_adfd1_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_adfd1_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_adfd1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_adfd1_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_adfd1_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_adfd1_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_adfd1_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_adfd1_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_adfd1_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.bar(vmin = 50, vmax = 100)
# Out:
# <style type="text/css">
# #T_540d4_row0_col2, #T_540d4_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.0%, transparent 38.0%);
# }
# #T_540d4_row0_col3, #T_540d4_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.0%, transparent 46.0%);
# }
# #T_540d4_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.0%, transparent 20.0%);
# }
# #T_540d4_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_540d4_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 76.0%, transparent 76.0%);
# }
# #T_540d4_row1_col4, #T_540d4_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.0%, transparent 22.0%);
# }
# #T_540d4_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.0%, transparent 4.0%);
# }
# #T_540d4_row2_col2, #T_540d4_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.0%, transparent 40.0%);
# }
# #T_540d4_row2_col3, #T_540d4_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.0%, transparent 44.0%);
# }
# #T_540d4_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.0%, transparent 34.0%);
# }
# #T_540d4_row2_col5, #T_540d4_row3_col5 {
#   width: 10em;
# }
# #T_540d4_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.0%, transparent 42.0%);
# }
# #T_540d4_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.0%, transparent 36.0%);
# }
# #T_540d4_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.0%, transparent 58.0%);
# }
# </style>
# <table id="T_540d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_540d4_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_540d4_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_540d4_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_540d4_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_540d4_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_540d4_level0_col5" class="col_heading level0 col5" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_540d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_540d4_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_540d4_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_540d4_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_540d4_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_540d4_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_540d4_row0_col5" class="data row0 col5" >60</td>
#     </tr>
#     <tr>
#       <th id="T_540d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_540d4_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_540d4_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_540d4_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_540d4_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_540d4_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_540d4_row1_col5" class="data row1 col5" >52</td>
#     </tr>
#     <tr>
#       <th id="T_540d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_540d4_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_540d4_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_540d4_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_540d4_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_540d4_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_540d4_row2_col5" class="data row2 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_540d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_540d4_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_540d4_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_540d4_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_540d4_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_540d4_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_540d4_row3_col5" class="data row3 col5" >34</td>
#     </tr>
#     <tr>
#       <th id="T_540d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_540d4_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_540d4_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_540d4_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_540d4_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_540d4_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_540d4_row4_col5" class="data row4 col5" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.assign(avg = df.mean(axis = 1, numeric_only = True)) 
 .assign(diff = lambda x: x.avg.diff()) # diff() calculate the first order difference
 .style
 .bar(color = 'yellow', subset = ['Q1'], vmin = 60, vmax = 80)
 .bar(subset = ['avg'], width=90,
      align = 'mid',
      vmin = 60, vmax = 80,
      color = '#5CADAD')
 .bar(subset = ['diff'],
      color = ['#ffe4e4','#bbf9ce'], 
      vmin = 0, vmax = 10, 
      align = 'zero')
)
# Out:
# <style type="text/css">
# #T_0eb95_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 45.0%, transparent 45.0%);
# }
# #T_0eb95_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5CADAD 34.9%, transparent 34.9%);
# }
# #T_0eb95_row0_col7, #T_0eb95_row2_col7 {
#   width: 10em;
# }
# #T_0eb95_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 85.0%, transparent 85.0%);
# }
# #T_0eb95_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5CADAD 42.8%, transparent 42.8%);
# }
# #T_0eb95_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #bbf9ce 50.0%, #bbf9ce 58.8%, transparent 58.8%);
# }
# #T_0eb95_row2_col2, #T_0eb95_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 50.0%, transparent 50.0%);
# }
# #T_0eb95_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5CADAD 3.4%, transparent 3.4%);
# }
# #T_0eb95_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 60.0%, transparent 60.0%);
# }
# #T_0eb95_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5CADAD 5.6%, transparent 5.6%);
# }
# #T_0eb95_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #bbf9ce 50.0%, #bbf9ce 52.5%, transparent 52.5%);
# }
# #T_0eb95_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5CADAD 48.4%, transparent 48.4%);
# }
# #T_0eb95_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #bbf9ce 50.0%, #bbf9ce 97.5%, transparent 97.5%);
# }
# </style>
# <table id="T_0eb95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eb95_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0eb95_level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_0eb95_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_0eb95_level0_col3" class="col_heading level0 col3" >Q2</th>
#       <th id="T_0eb95_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_0eb95_level0_col5" class="col_heading level0 col5" >Q4</th>
#       <th id="T_0eb95_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_0eb95_level0_col7" class="col_heading level0 col7" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eb95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0eb95_row0_col0" class="data row0 col0" >James</td>
#       <td id="T_0eb95_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_0eb95_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_0eb95_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_0eb95_row0_col4" class="data row0 col4" >69</td>
#       <td id="T_0eb95_row0_col5" class="data row0 col5" >60</td>
#       <td id="T_0eb95_row0_col6" class="data row0 col6" >67.750000</td>
#       <td id="T_0eb95_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0eb95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0eb95_row1_col0" class="data row1 col0" >Messi</td>
#       <td id="T_0eb95_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_0eb95_row1_col2" class="data row1 col2" >77</td>
#       <td id="T_0eb95_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_0eb95_row1_col4" class="data row1 col4" >61</td>
#       <td id="T_0eb95_row1_col5" class="data row1 col5" >52</td>
#       <td id="T_0eb95_row1_col6" class="data row1 col6" >69.500000</td>
#       <td id="T_0eb95_row1_col7" class="data row1 col7" >1.750000</td>
#     </tr>
#     <tr>
#       <th id="T_0eb95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0eb95_row2_col0" class="data row2 col0" >Durant</td>
#       <td id="T_0eb95_row2_col1" class="data row2 col1" >C</td>
#       <td id="T_0eb95_row2_col2" class="data row2 col2" >70</td>
#       <td id="T_0eb95_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_0eb95_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_0eb95_row2_col5" class="data row2 col5" >34</td>
#       <td id="T_0eb95_row2_col6" class="data row2 col6" >60.750000</td>
#       <td id="T_0eb95_row2_col7" class="data row2 col7" >-8.750000</td>
#     </tr>
#     <tr>
#       <th id="T_0eb95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0eb95_row3_col0" class="data row3 col0" >Irvine</td>
#       <td id="T_0eb95_row3_col1" class="data row3 col1" >D</td>
#       <td id="T_0eb95_row3_col2" class="data row3 col2" >72</td>
#       <td id="T_0eb95_row3_col3" class="data row3 col3" >71</td>
#       <td id="T_0eb95_row3_col4" class="data row3 col4" >68</td>
#       <td id="T_0eb95_row3_col5" class="data row3 col5" >34</td>
#       <td id="T_0eb95_row3_col6" class="data row3 col6" >61.250000</td>
#       <td id="T_0eb95_row3_col7" class="data row3 col7" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_0eb95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0eb95_row4_col0" class="data row4 col0" >Harden</td>
#       <td id="T_0eb95_row4_col1" class="data row4 col1" >E</td>
#       <td id="T_0eb95_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_0eb95_row4_col3" class="data row4 col3" >79</td>
#       <td id="T_0eb95_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_0eb95_row4_col5" class="data row4 col5" >73</td>
#       <td id="T_0eb95_row4_col6" class="data row4 col6" >70.750000</td>
#       <td id="T_0eb95_row4_col7" class="data row4 col7" >9.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Formatting
# Common formatting techniques include adding currency symbols, percentages, and thousands separators. Pandas provides the `.format` method within the Styler class to facilitate data formatting.
#
# The `.format` method allows you to apply formatting options to the displayed values in a DataFrame or Series. It supports various formatting options, such as specifying the number of decimal places, adding currency symbols, controlling alignment, and applying custom formatting patterns.

# %% [markdown]
# ## Syntax
# ```python
# Styler.format(self, formatter,
#               subset=None,
#               na_rep: Union[str, NoneType] = None)
#
# formatter(str, callable, dict or None)
# ```
# ##### `formatter`: This can be a string, callable, dictionary, or None.
#
# * If formatter is a string, it specifies a format string that will be applied to the selected columns or subsets. You can use formatting placeholders like {} or {:.2f} to define the desired format. For example, '{:.2%}' would format a column as a percentage with 2 decimal places.
#
# * If formatter is a callable, it should be a function that takes a value as input and returns a formatted string. The function will be applied to each element in the selected columns or subsets.
#
# * If formatter is a dictionary, it maps column names or subsets to format strings or callables. Each column or subset will be formatted according to its corresponding format specified in the dictionary.
#
# * If formatter is None, no formatting will be applied to the selected columns or subsets.
#
# ##### `subset`: This parameter specifies the columns or subsets to which the formatting should be applied. It can be a single column name, a list of column names, or a callable that returns a boolean Series indicating the desired subset.
#
# ##### `na_rep`: This parameter specifies the string representation to use for missing values (NaN). It defaults to None, which uses the default representation.

# %% [markdown]
# ## Example

# %%
data = {
    'Country': ['USA', 'Canada', 'Germany', 'Japan', 'Australia'],
    'Population': [328.2, 37.6, 83.0, 126.5, 25.4],
    'GDP': [21.43, 1.64, 4.42, 5.15, 1.39],
    'Area (sq km)': [9629091, 9976140, 357022, 377915, 7692024]
}
df = pd.DataFrame(data)
df
# Out:
#      Country  Population    GDP  Area (sq km)
# 0        USA       328.2  21.43       9629091
# 1     Canada        37.6   1.64       9976140
# 2    Germany        83.0   4.42        357022
# 3      Japan       126.5   5.15        377915
# 4  Australia        25.4   1.39       7692024

# %%
df.style.format("{:.1f}", subset = ['GDP', 'Population'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4196">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4196_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_a4196_level0_col1" class="col_heading level0 col1" >Population</th>
#       <th id="T_a4196_level0_col2" class="col_heading level0 col2" >GDP</th>
#       <th id="T_a4196_level0_col3" class="col_heading level0 col3" >Area (sq km)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4196_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4196_row0_col0" class="data row0 col0" >USA</td>
#       <td id="T_a4196_row0_col1" class="data row0 col1" >328.2</td>
#       <td id="T_a4196_row0_col2" class="data row0 col2" >21.4</td>
#       <td id="T_a4196_row0_col3" class="data row0 col3" >9629091</td>
#     </tr>
#     <tr>
#       <th id="T_a4196_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4196_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_a4196_row1_col1" class="data row1 col1" >37.6</td>
#       <td id="T_a4196_row1_col2" class="data row1 col2" >1.6</td>
#       <td id="T_a4196_row1_col3" class="data row1 col3" >9976140</td>
#     </tr>
#     <tr>
#       <th id="T_a4196_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4196_row2_col0" class="data row2 col0" >Germany</td>
#       <td id="T_a4196_row2_col1" class="data row2 col1" >83.0</td>
#       <td id="T_a4196_row2_col2" class="data row2 col2" >4.4</td>
#       <td id="T_a4196_row2_col3" class="data row2 col3" >357022</td>
#     </tr>
#     <tr>
#       <th id="T_a4196_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4196_row3_col0" class="data row3 col0" >Japan</td>
#       <td id="T_a4196_row3_col1" class="data row3 col1" >126.5</td>
#       <td id="T_a4196_row3_col2" class="data row3 col2" >5.2</td>
#       <td id="T_a4196_row3_col3" class="data row3 col3" >377915</td>
#     </tr>
#     <tr>
#       <th id="T_a4196_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4196_row4_col0" class="data row4 col0" >Australia</td>
#       <td id="T_a4196_row4_col1" class="data row4 col1" >25.4</td>
#       <td id="T_a4196_row4_col2" class="data row4 col2" >1.4</td>
#       <td id="T_a4196_row4_col3" class="data row4 col3" >7692024</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Specify the columns to be all upper case
df.style.format({'Country': str.upper})
# Out:
# <style type="text/css">
# </style>
# <table id="T_97908">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97908_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_97908_level0_col1" class="col_heading level0 col1" >Population</th>
#       <th id="T_97908_level0_col2" class="col_heading level0 col2" >GDP</th>
#       <th id="T_97908_level0_col3" class="col_heading level0 col3" >Area (sq km)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97908_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97908_row0_col0" class="data row0 col0" >USA</td>
#       <td id="T_97908_row0_col1" class="data row0 col1" >328.200000</td>
#       <td id="T_97908_row0_col2" class="data row0 col2" >21.430000</td>
#       <td id="T_97908_row0_col3" class="data row0 col3" >9629091</td>
#     </tr>
#     <tr>
#       <th id="T_97908_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97908_row1_col0" class="data row1 col0" >CANADA</td>
#       <td id="T_97908_row1_col1" class="data row1 col1" >37.600000</td>
#       <td id="T_97908_row1_col2" class="data row1 col2" >1.640000</td>
#       <td id="T_97908_row1_col3" class="data row1 col3" >9976140</td>
#     </tr>
#     <tr>
#       <th id="T_97908_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97908_row2_col0" class="data row2 col0" >GERMANY</td>
#       <td id="T_97908_row2_col1" class="data row2 col1" >83.000000</td>
#       <td id="T_97908_row2_col2" class="data row2 col2" >4.420000</td>
#       <td id="T_97908_row2_col3" class="data row2 col3" >357022</td>
#     </tr>
#     <tr>
#       <th id="T_97908_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97908_row3_col0" class="data row3 col0" >JAPAN</td>
#       <td id="T_97908_row3_col1" class="data row3 col1" >126.500000</td>
#       <td id="T_97908_row3_col2" class="data row3 col2" >5.150000</td>
#       <td id="T_97908_row3_col3" class="data row3 col3" >377915</td>
#     </tr>
#     <tr>
#       <th id="T_97908_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97908_row4_col0" class="data row4 col0" >AUSTRALIA</td>
#       <td id="T_97908_row4_col1" class="data row4 col1" >25.400000</td>
#       <td id="T_97908_row4_col2" class="data row4 col2" >1.390000</td>
#       <td id="T_97908_row4_col3" class="data row4 col3" >7692024</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.format({"GDP": lambda x: "+{:.2f}Trillion".format(abs(x))})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cf750">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf750_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_cf750_level0_col1" class="col_heading level0 col1" >Population</th>
#       <th id="T_cf750_level0_col2" class="col_heading level0 col2" >GDP</th>
#       <th id="T_cf750_level0_col3" class="col_heading level0 col3" >Area (sq km)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf750_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf750_row0_col0" class="data row0 col0" >USA</td>
#       <td id="T_cf750_row0_col1" class="data row0 col1" >328.200000</td>
#       <td id="T_cf750_row0_col2" class="data row0 col2" >+21.43Trillion</td>
#       <td id="T_cf750_row0_col3" class="data row0 col3" >9629091</td>
#     </tr>
#     <tr>
#       <th id="T_cf750_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf750_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_cf750_row1_col1" class="data row1 col1" >37.600000</td>
#       <td id="T_cf750_row1_col2" class="data row1 col2" >+1.64Trillion</td>
#       <td id="T_cf750_row1_col3" class="data row1 col3" >9976140</td>
#     </tr>
#     <tr>
#       <th id="T_cf750_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf750_row2_col0" class="data row2 col0" >Germany</td>
#       <td id="T_cf750_row2_col1" class="data row2 col1" >83.000000</td>
#       <td id="T_cf750_row2_col2" class="data row2 col2" >+4.42Trillion</td>
#       <td id="T_cf750_row2_col3" class="data row2 col3" >357022</td>
#     </tr>
#     <tr>
#       <th id="T_cf750_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf750_row3_col0" class="data row3 col0" >Japan</td>
#       <td id="T_cf750_row3_col1" class="data row3 col1" >126.500000</td>
#       <td id="T_cf750_row3_col2" class="data row3 col2" >+5.15Trillion</td>
#       <td id="T_cf750_row3_col3" class="data row3 col3" >377915</td>
#     </tr>
#     <tr>
#       <th id="T_cf750_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf750_row4_col0" class="data row4 col0" >Australia</td>
#       <td id="T_cf750_row4_col1" class="data row4 col1" >25.400000</td>
#       <td id="T_cf750_row4_col2" class="data row4 col2" >+1.39Trillion</td>
#       <td id="T_cf750_row4_col3" class="data row4 col3" >7692024</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = {
    'Name': ['John', 'Emma', 'Michael', 'Sophia', 'William', 'Olivia', 'James'],
    'Grade_Semester1': [80, 85, 90, 92, 78, 88, 90],
    'Grade_Semester2': [88, 92, 87, 85, 90, 95, 82],
    'Grade_Semester3': [95, 90, 88, 92, 85, 90, 88],
    'Tuition_Fees': [5000, 5500, 6000, 6500, 7000, 5500, 6000]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Grade_Semester1  Grade_Semester2  Grade_Semester3  Tuition_Fees
# 0     John               80               88               95          5000
# 1     Emma               85               92               90          5500
# 2  Michael               90               87               88          6000
# 3   Sophia               92               85               92          6500
# 4  William               78               90               85          7000
# 5   Olivia               88               95               90          5500
# 6    James               90               82               88          6000

# %%
# A genral case use the chain rule
(df.assign(avg = df.mean(axis = 1, numeric_only = True)/100) 
 .assign(diff = lambda x: x.avg.diff()) 
 .style
 .format({'Name': str.upper, 'avg': "{:.2f}", 'diff': "{:.2f}"}, na_rep = "-")
)  # Put all the format in the dictionary
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc70b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc70b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_cc70b_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_cc70b_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_cc70b_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_cc70b_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#       <th id="T_cc70b_level0_col5" class="col_heading level0 col5" >avg</th>
#       <th id="T_cc70b_level0_col6" class="col_heading level0 col6" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc70b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc70b_row0_col0" class="data row0 col0" >JOHN</td>
#       <td id="T_cc70b_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_cc70b_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_cc70b_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_cc70b_row0_col4" class="data row0 col4" >5000</td>
#       <td id="T_cc70b_row0_col5" class="data row0 col5" >13.16</td>
#       <td id="T_cc70b_row0_col6" class="data row0 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc70b_row1_col0" class="data row1 col0" >EMMA</td>
#       <td id="T_cc70b_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_cc70b_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_cc70b_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_cc70b_row1_col4" class="data row1 col4" >5500</td>
#       <td id="T_cc70b_row1_col5" class="data row1 col5" >14.42</td>
#       <td id="T_cc70b_row1_col6" class="data row1 col6" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc70b_row2_col0" class="data row2 col0" >MICHAEL</td>
#       <td id="T_cc70b_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_cc70b_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_cc70b_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_cc70b_row2_col4" class="data row2 col4" >6000</td>
#       <td id="T_cc70b_row2_col5" class="data row2 col5" >15.66</td>
#       <td id="T_cc70b_row2_col6" class="data row2 col6" >1.24</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc70b_row3_col0" class="data row3 col0" >SOPHIA</td>
#       <td id="T_cc70b_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_cc70b_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_cc70b_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_cc70b_row3_col4" class="data row3 col4" >6500</td>
#       <td id="T_cc70b_row3_col5" class="data row3 col5" >16.92</td>
#       <td id="T_cc70b_row3_col6" class="data row3 col6" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc70b_row4_col0" class="data row4 col0" >WILLIAM</td>
#       <td id="T_cc70b_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_cc70b_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_cc70b_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_cc70b_row4_col4" class="data row4 col4" >7000</td>
#       <td id="T_cc70b_row4_col5" class="data row4 col5" >18.13</td>
#       <td id="T_cc70b_row4_col6" class="data row4 col6" >1.21</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc70b_row5_col0" class="data row5 col0" >OLIVIA</td>
#       <td id="T_cc70b_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_cc70b_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_cc70b_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_cc70b_row5_col4" class="data row5 col4" >5500</td>
#       <td id="T_cc70b_row5_col5" class="data row5 col5" >14.43</td>
#       <td id="T_cc70b_row5_col6" class="data row5 col6" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_cc70b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc70b_row6_col0" class="data row6 col0" >JAMES</td>
#       <td id="T_cc70b_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_cc70b_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_cc70b_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_cc70b_row6_col4" class="data row6 col4" >6000</td>
#       <td id="T_cc70b_row6_col5" class="data row6 col5" >15.65</td>
#       <td id="T_cc70b_row6_col6" class="data row6 col6" >1.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Formatting Configuration
# Pandas provides some options for configuring styles in a more systematic way, eliminating the need for individual settings. It also offers additional methods to enrich the output of styled content.

# %% [markdown]
# ## Add a caption to the table

# %%
df.style.set_caption("Student Grades and Tuition Fees")
# Out:
# <style type="text/css">
# </style>
# <table id="T_215ff">
#   <caption>Student Grades and Tuition Fees</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_215ff_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_215ff_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_215ff_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_215ff_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_215ff_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_215ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_215ff_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_215ff_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_215ff_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_215ff_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_215ff_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_215ff_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_215ff_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_215ff_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_215ff_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_215ff_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_215ff_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_215ff_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_215ff_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_215ff_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_215ff_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_215ff_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_215ff_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_215ff_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_215ff_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_215ff_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_215ff_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_215ff_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_215ff_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_215ff_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_215ff_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_215ff_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_215ff_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_215ff_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_215ff_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_215ff_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_215ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_215ff_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_215ff_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_215ff_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_215ff_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_215ff_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# To align the caption in the middle, use CCS styling within the set_caption()
df.style.set_caption("<div style='text-align: center;'>Student Grades and Tuition Fees</div>")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8dc0">
#   <caption><div style='text-align: center;'>Student Grades and Tuition Fees</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8dc0_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e8dc0_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_e8dc0_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_e8dc0_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_e8dc0_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8dc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8dc0_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_e8dc0_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_e8dc0_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_e8dc0_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_e8dc0_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8dc0_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_e8dc0_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_e8dc0_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_e8dc0_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_e8dc0_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8dc0_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_e8dc0_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_e8dc0_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_e8dc0_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_e8dc0_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8dc0_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_e8dc0_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_e8dc0_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_e8dc0_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_e8dc0_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8dc0_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_e8dc0_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_e8dc0_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_e8dc0_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_e8dc0_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8dc0_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_e8dc0_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_e8dc0_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_e8dc0_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_e8dc0_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_e8dc0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8dc0_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_e8dc0_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_e8dc0_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_e8dc0_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_e8dc0_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Precision
# Set the global data precision.

# %%
df1 = df.assign(avg = df.mean(axis = 1, numeric_only = True)/100) .assign(diff = lambda x: x.avg.diff()) 

df1
# Out:
#       Name  Grade_Semester1  Grade_Semester2  Grade_Semester3  Tuition_Fees  \
# 0     John               80               88               95          5000
# 1     Emma               85               92               90          5500
# 2  Michael               90               87               88          6000
# 3   Sophia               92               85               92          6500
# 4  William               78               90               85          7000
# 5   Olivia               88               95               90          5500
# 6    James               90               82               88          6000
#
#        avg    diff
# 0  13.1575     NaN
# 1  14.4175  1.2600
# 2  15.6625  1.2450
# 3  16.9225  1.2600
# 4  18.1325  1.2100
# 5  14.4325 -3.7000
# 6  15.6500  1.2175

# %%
df1.style.format(precision = 2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca115">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca115_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_ca115_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_ca115_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_ca115_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_ca115_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#       <th id="T_ca115_level0_col5" class="col_heading level0 col5" >avg</th>
#       <th id="T_ca115_level0_col6" class="col_heading level0 col6" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca115_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_ca115_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_ca115_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_ca115_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_ca115_row0_col4" class="data row0 col4" >5000</td>
#       <td id="T_ca115_row0_col5" class="data row0 col5" >13.16</td>
#       <td id="T_ca115_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca115_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_ca115_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_ca115_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_ca115_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_ca115_row1_col4" class="data row1 col4" >5500</td>
#       <td id="T_ca115_row1_col5" class="data row1 col5" >14.42</td>
#       <td id="T_ca115_row1_col6" class="data row1 col6" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca115_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_ca115_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_ca115_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_ca115_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_ca115_row2_col4" class="data row2 col4" >6000</td>
#       <td id="T_ca115_row2_col5" class="data row2 col5" >15.66</td>
#       <td id="T_ca115_row2_col6" class="data row2 col6" >1.24</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca115_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_ca115_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_ca115_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_ca115_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_ca115_row3_col4" class="data row3 col4" >6500</td>
#       <td id="T_ca115_row3_col5" class="data row3 col5" >16.92</td>
#       <td id="T_ca115_row3_col6" class="data row3 col6" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca115_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_ca115_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_ca115_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_ca115_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_ca115_row4_col4" class="data row4 col4" >7000</td>
#       <td id="T_ca115_row4_col5" class="data row4 col5" >18.13</td>
#       <td id="T_ca115_row4_col6" class="data row4 col6" >1.21</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca115_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_ca115_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_ca115_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_ca115_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_ca115_row5_col4" class="data row5 col4" >5500</td>
#       <td id="T_ca115_row5_col5" class="data row5 col5" >14.43</td>
#       <td id="T_ca115_row5_col6" class="data row5 col6" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_ca115_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca115_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_ca115_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_ca115_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_ca115_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_ca115_row6_col4" class="data row6 col4" >6000</td>
#       <td id="T_ca115_row6_col5" class="data row6 col5" >15.65</td>
#       <td id="T_ca115_row6_col6" class="data row6 col6" >1.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Missing values

# %%
df1.style.format(na_rep = 'Missing')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c42b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c42b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_6c42b_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_6c42b_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_6c42b_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_6c42b_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#       <th id="T_6c42b_level0_col5" class="col_heading level0 col5" >avg</th>
#       <th id="T_6c42b_level0_col6" class="col_heading level0 col6" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c42b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c42b_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_6c42b_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_6c42b_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_6c42b_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_6c42b_row0_col4" class="data row0 col4" >5000</td>
#       <td id="T_6c42b_row0_col5" class="data row0 col5" >13.157500</td>
#       <td id="T_6c42b_row0_col6" class="data row0 col6" >Missing</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c42b_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_6c42b_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_6c42b_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_6c42b_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_6c42b_row1_col4" class="data row1 col4" >5500</td>
#       <td id="T_6c42b_row1_col5" class="data row1 col5" >14.417500</td>
#       <td id="T_6c42b_row1_col6" class="data row1 col6" >1.260000</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c42b_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_6c42b_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_6c42b_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_6c42b_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_6c42b_row2_col4" class="data row2 col4" >6000</td>
#       <td id="T_6c42b_row2_col5" class="data row2 col5" >15.662500</td>
#       <td id="T_6c42b_row2_col6" class="data row2 col6" >1.245000</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c42b_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_6c42b_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_6c42b_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_6c42b_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_6c42b_row3_col4" class="data row3 col4" >6500</td>
#       <td id="T_6c42b_row3_col5" class="data row3 col5" >16.922500</td>
#       <td id="T_6c42b_row3_col6" class="data row3 col6" >1.260000</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c42b_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_6c42b_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_6c42b_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_6c42b_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_6c42b_row4_col4" class="data row4 col4" >7000</td>
#       <td id="T_6c42b_row4_col5" class="data row4 col5" >18.132500</td>
#       <td id="T_6c42b_row4_col6" class="data row4 col6" >1.210000</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c42b_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_6c42b_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_6c42b_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_6c42b_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_6c42b_row5_col4" class="data row5 col4" >5500</td>
#       <td id="T_6c42b_row5_col5" class="data row5 col5" >14.432500</td>
#       <td id="T_6c42b_row5_col6" class="data row5 col6" >-3.700000</td>
#     </tr>
#     <tr>
#       <th id="T_6c42b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6c42b_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_6c42b_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_6c42b_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_6c42b_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_6c42b_row6_col4" class="data row6 col4" >6000</td>
#       <td id="T_6c42b_row6_col5" class="data row6 col5" >15.650000</td>
#       <td id="T_6c42b_row6_col6" class="data row6 col6" >1.217500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hide index and column

# %%
df.head().style.hide(axis = 'index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3967">
#   <thead>
#     <tr>
#       <th id="T_e3967_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e3967_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_e3967_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_e3967_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_e3967_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3967_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_e3967_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_e3967_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_e3967_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_e3967_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <td id="T_e3967_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_e3967_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_e3967_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_e3967_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_e3967_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <td id="T_e3967_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_e3967_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_e3967_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_e3967_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_e3967_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <td id="T_e3967_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_e3967_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_e3967_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_e3967_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_e3967_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <td id="T_e3967_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_e3967_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_e3967_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_e3967_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_e3967_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.hide(subset=['Grade_Semester1', 'Grade_Semester2'], axis = 'columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c4135">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4135_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_c4135_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_c4135_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4135_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4135_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_c4135_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_c4135_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4135_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_c4135_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_c4135_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4135_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_c4135_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_c4135_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4135_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_c4135_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_c4135_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4135_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_c4135_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_c4135_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4135_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_c4135_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_c4135_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_c4135_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4135_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_c4135_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_c4135_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Table styles
# To set inline styles using set_properties in Pandas, you can pass a dictionary of CSS properties and values to the `set_properties` method. Each key-value pair in the dictionary represents a CSS property and its corresponding value.

# %%
# Specify the column to set the font color to red
df.style.set_properties(subset = ['Grade_Semester1'], **{'background-color': 'lightblue','color': 'red'})
# Out:
# <style type="text/css">
# #T_6faab_row0_col1, #T_6faab_row1_col1, #T_6faab_row2_col1, #T_6faab_row3_col1, #T_6faab_row4_col1, #T_6faab_row5_col1, #T_6faab_row6_col1 {
#   background-color: lightblue;
#   color: red;
# }
# </style>
# <table id="T_6faab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6faab_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_6faab_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_6faab_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_6faab_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_6faab_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6faab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6faab_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_6faab_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_6faab_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_6faab_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_6faab_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6faab_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_6faab_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_6faab_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_6faab_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_6faab_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6faab_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_6faab_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_6faab_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_6faab_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_6faab_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6faab_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_6faab_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_6faab_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_6faab_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_6faab_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6faab_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_6faab_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_6faab_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_6faab_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_6faab_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6faab_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_6faab_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_6faab_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_6faab_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_6faab_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_6faab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6faab_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_6faab_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_6faab_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_6faab_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_6faab_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.set_properties(color ="blue", align = "right")
# Out:
# <style type="text/css">
# #T_be907_row0_col0, #T_be907_row0_col1, #T_be907_row0_col2, #T_be907_row0_col3, #T_be907_row0_col4, #T_be907_row1_col0, #T_be907_row1_col1, #T_be907_row1_col2, #T_be907_row1_col3, #T_be907_row1_col4, #T_be907_row2_col0, #T_be907_row2_col1, #T_be907_row2_col2, #T_be907_row2_col3, #T_be907_row2_col4, #T_be907_row3_col0, #T_be907_row3_col1, #T_be907_row3_col2, #T_be907_row3_col3, #T_be907_row3_col4, #T_be907_row4_col0, #T_be907_row4_col1, #T_be907_row4_col2, #T_be907_row4_col3, #T_be907_row4_col4 {
#   color: blue;
#   align: right;
# }
# </style>
# <table id="T_be907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be907_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_be907_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_be907_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_be907_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_be907_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be907_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be907_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_be907_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_be907_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_be907_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_be907_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_be907_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be907_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_be907_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_be907_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_be907_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_be907_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_be907_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be907_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_be907_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_be907_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_be907_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_be907_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_be907_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be907_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_be907_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_be907_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_be907_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_be907_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_be907_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be907_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_be907_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_be907_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_be907_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_be907_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.set_properties(**{'width': '100px', 'font-size': '18px'})
# Out:
# <style type="text/css">
# #T_958ca_row0_col0, #T_958ca_row0_col1, #T_958ca_row0_col2, #T_958ca_row0_col3, #T_958ca_row0_col4, #T_958ca_row1_col0, #T_958ca_row1_col1, #T_958ca_row1_col2, #T_958ca_row1_col3, #T_958ca_row1_col4, #T_958ca_row2_col0, #T_958ca_row2_col1, #T_958ca_row2_col2, #T_958ca_row2_col3, #T_958ca_row2_col4, #T_958ca_row3_col0, #T_958ca_row3_col1, #T_958ca_row3_col2, #T_958ca_row3_col3, #T_958ca_row3_col4, #T_958ca_row4_col0, #T_958ca_row4_col1, #T_958ca_row4_col2, #T_958ca_row4_col3, #T_958ca_row4_col4 {
#   width: 100px;
#   font-size: 18px;
# }
# </style>
# <table id="T_958ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_958ca_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_958ca_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_958ca_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_958ca_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_958ca_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_958ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_958ca_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_958ca_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_958ca_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_958ca_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_958ca_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_958ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_958ca_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_958ca_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_958ca_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_958ca_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_958ca_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_958ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_958ca_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_958ca_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_958ca_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_958ca_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_958ca_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_958ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_958ca_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_958ca_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_958ca_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_958ca_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_958ca_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_958ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_958ca_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_958ca_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_958ca_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_958ca_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_958ca_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# #T_7f9c1_row0_col0, #T_7f9c1_row0_col1, #T_7f9c1_row0_col2, #T_7f9c1_row0_col3, #T_7f9c1_row0_col4, #T_7f9c1_row1_col0, #T_7f9c1_row1_col1, #T_7f9c1_row1_col2, #T_7f9c1_row1_col3, #T_7f9c1_row1_col4, #T_7f9c1_row2_col0, #T_7f9c1_row2_col1, #T_7f9c1_row2_col2, #T_7f9c1_row2_col3, #T_7f9c1_row2_col4, #T_7f9c1_row3_col0, #T_7f9c1_row3_col1, #T_7f9c1_row3_col2, #T_7f9c1_row3_col3, #T_7f9c1_row3_col4, #T_7f9c1_row4_col0, #T_7f9c1_row4_col1, #T_7f9c1_row4_col2, #T_7f9c1_row4_col3, #T_7f9c1_row4_col4 {
#   background-color: black;
#   color: lawngreen;
#   border-color: white;
# }
# </style>
# <table id="T_7f9c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f9c1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7f9c1_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_7f9c1_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_7f9c1_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_7f9c1_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f9c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f9c1_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_7f9c1_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_7f9c1_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_7f9c1_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_7f9c1_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f9c1_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_7f9c1_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_7f9c1_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_7f9c1_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_7f9c1_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_7f9c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f9c1_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_7f9c1_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_7f9c1_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_7f9c1_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_7f9c1_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f9c1_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_7f9c1_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_7f9c1_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_7f9c1_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_7f9c1_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_7f9c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f9c1_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_7f9c1_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_7f9c1_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_7f9c1_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_7f9c1_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## set_table_attributes
# Add label properteis to `table`
#
# **Bootstrap**: Bootstrap is a popular CSS framework that provides a variety of table styles. Some of the Bootstrap table classes include:
#
# * "table": Basic table styling.
# * "table-striped": Alternating row colors.
# * "table-bordered": Borders around cells and table.
# * "table-hover": Highlight row on hover.
# * "table-responsive": Enable horizontal scrolling for responsive tables.
#
# **Bulma**: Bulma is a lightweight CSS framework with its own set of table classes. Some of the Bulma table classes include:
#
# * "table": Basic table styling.
# * "is-striped": Alternating row colors.
# * "is-bordered": Borders around cells and table.
# * "is-hoverable": Highlight row on hover.
# * "is-fullwidth": Make the table full width.
#
# **Foundation**: Foundation is another CSS framework with its own table classes. Some of the Foundation table classes include:
#
# * "table": Basic table styling.
# * "striped": Alternating row colors.
# * "bordered": Borders around cells and table.
# * "hover": Highlight row on hover.
# * "responsive": Enable horizontal scrolling for responsive tables.

# %%
df.head().style.set_table_attributes('class = "table-bordered"')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d45e3" class = "table-bordered">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d45e3_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_d45e3_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_d45e3_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_d45e3_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_d45e3_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d45e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d45e3_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_d45e3_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_d45e3_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_d45e3_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_d45e3_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_d45e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d45e3_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_d45e3_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_d45e3_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_d45e3_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_d45e3_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_d45e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d45e3_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_d45e3_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_d45e3_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_d45e3_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_d45e3_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_d45e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d45e3_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_d45e3_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_d45e3_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_d45e3_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_d45e3_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_d45e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d45e3_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_d45e3_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_d45e3_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_d45e3_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_d45e3_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Style apply function
# The `Styler` object in pandas provides `apply()` and `applymap()` methods that allow you to define more complex styling functions. These functions can be applied to specific cells, rows, columns, or the entire table.

# %% [markdown]
# ### Applying functions
# In pandas Styler, there are two methods for applying functions to style the DataFrame:
#
# * `Styler.applymap`: This method applies a function to every element of the DataFrame.
#
# * `Styler.apply`: This method applies a function to either columns, rows, or the entire DataFrame, based on the axis parameter.
#
# Here is a brief explanation of each method:
#
# * `Styler.applymap`: This method applies a function to every individual element in the DataFrame. It is useful when you want to style each element independently based on its value. For example, you can define a function that returns a CSS string based on the value of each element, and then apply this function using `applymap()

# %%
def apply_even_columns_style(value):
    if isinstance(value, (int, float)):
        return 'color: blue'
    else:
        return ''

df.style.applymap(apply_even_columns_style, subset=pd.IndexSlice[:, ::2])
# Out:
# <style type="text/css">
# #T_3629f_row0_col2, #T_3629f_row0_col4, #T_3629f_row1_col2, #T_3629f_row1_col4, #T_3629f_row2_col2, #T_3629f_row2_col4, #T_3629f_row3_col2, #T_3629f_row3_col4, #T_3629f_row4_col2, #T_3629f_row4_col4, #T_3629f_row5_col2, #T_3629f_row5_col4, #T_3629f_row6_col2, #T_3629f_row6_col4 {
#   color: blue;
# }
# </style>
# <table id="T_3629f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3629f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_3629f_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_3629f_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_3629f_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_3629f_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3629f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3629f_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_3629f_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_3629f_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_3629f_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_3629f_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3629f_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_3629f_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_3629f_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_3629f_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_3629f_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3629f_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_3629f_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_3629f_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_3629f_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_3629f_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3629f_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_3629f_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_3629f_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_3629f_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_3629f_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3629f_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_3629f_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_3629f_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_3629f_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_3629f_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3629f_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_3629f_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_3629f_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_3629f_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_3629f_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_3629f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3629f_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_3629f_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_3629f_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_3629f_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_3629f_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * `Styler.apply`: This method applies a function to either columns, rows, or the entire DataFrame based on the axis parameter. By default, `axis=0` applies the function to each column, while `axis=1` applies it to each row. If you want to apply the function to the entire DataFrame, we can set axis=None.

# %%
def highlight_gt90(series):
    return ['color: red' if value >= 90 else 'color: black' for value in series]

df.loc[:, 'Grade_Semester1':'Grade_Semester3'].style.apply(lambda series: highlight_gt90(series))
# Out:
# <style type="text/css">
# #T_e4d08_row0_col0, #T_e4d08_row0_col1, #T_e4d08_row1_col0, #T_e4d08_row2_col1, #T_e4d08_row2_col2, #T_e4d08_row3_col1, #T_e4d08_row4_col0, #T_e4d08_row4_col2, #T_e4d08_row5_col0, #T_e4d08_row6_col1, #T_e4d08_row6_col2 {
#   color: black;
# }
# #T_e4d08_row0_col2, #T_e4d08_row1_col1, #T_e4d08_row1_col2, #T_e4d08_row2_col0, #T_e4d08_row3_col0, #T_e4d08_row3_col2, #T_e4d08_row4_col1, #T_e4d08_row5_col1, #T_e4d08_row5_col2, #T_e4d08_row6_col0 {
#   color: red;
# }
# </style>
# <table id="T_e4d08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4d08_level0_col0" class="col_heading level0 col0" >Grade_Semester1</th>
#       <th id="T_e4d08_level0_col1" class="col_heading level0 col1" >Grade_Semester2</th>
#       <th id="T_e4d08_level0_col2" class="col_heading level0 col2" >Grade_Semester3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4d08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4d08_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_e4d08_row0_col1" class="data row0 col1" >88</td>
#       <td id="T_e4d08_row0_col2" class="data row0 col2" >95</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4d08_row1_col0" class="data row1 col0" >85</td>
#       <td id="T_e4d08_row1_col1" class="data row1 col1" >92</td>
#       <td id="T_e4d08_row1_col2" class="data row1 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4d08_row2_col0" class="data row2 col0" >90</td>
#       <td id="T_e4d08_row2_col1" class="data row2 col1" >87</td>
#       <td id="T_e4d08_row2_col2" class="data row2 col2" >88</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4d08_row3_col0" class="data row3 col0" >92</td>
#       <td id="T_e4d08_row3_col1" class="data row3 col1" >85</td>
#       <td id="T_e4d08_row3_col2" class="data row3 col2" >92</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4d08_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_e4d08_row4_col1" class="data row4 col1" >90</td>
#       <td id="T_e4d08_row4_col2" class="data row4 col2" >85</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4d08_row5_col0" class="data row5 col0" >88</td>
#       <td id="T_e4d08_row5_col1" class="data row5 col1" >95</td>
#       <td id="T_e4d08_row5_col2" class="data row5 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_e4d08_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4d08_row6_col0" class="data row6 col0" >90</td>
#       <td id="T_e4d08_row6_col1" class="data row6 col1" >82</td>
#       <td id="T_e4d08_row6_col2" class="data row6 col2" >88</td>
#     </tr>
#   </tbody>
# </table>

# %%
def highlight_max(row):
    return ['background-color: yellow' if value == row.max() else '' for value in row]

df.iloc[:, 1:4].style.apply(highlight_max, axis = 1)
# Out:
# <style type="text/css">
# #T_046a3_row0_col2, #T_046a3_row1_col1, #T_046a3_row2_col0, #T_046a3_row3_col0, #T_046a3_row3_col2, #T_046a3_row4_col1, #T_046a3_row5_col1, #T_046a3_row6_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_046a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_046a3_level0_col0" class="col_heading level0 col0" >Grade_Semester1</th>
#       <th id="T_046a3_level0_col1" class="col_heading level0 col1" >Grade_Semester2</th>
#       <th id="T_046a3_level0_col2" class="col_heading level0 col2" >Grade_Semester3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_046a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_046a3_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_046a3_row0_col1" class="data row0 col1" >88</td>
#       <td id="T_046a3_row0_col2" class="data row0 col2" >95</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_046a3_row1_col0" class="data row1 col0" >85</td>
#       <td id="T_046a3_row1_col1" class="data row1 col1" >92</td>
#       <td id="T_046a3_row1_col2" class="data row1 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_046a3_row2_col0" class="data row2 col0" >90</td>
#       <td id="T_046a3_row2_col1" class="data row2 col1" >87</td>
#       <td id="T_046a3_row2_col2" class="data row2 col2" >88</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_046a3_row3_col0" class="data row3 col0" >92</td>
#       <td id="T_046a3_row3_col1" class="data row3 col1" >85</td>
#       <td id="T_046a3_row3_col2" class="data row3 col2" >92</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_046a3_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_046a3_row4_col1" class="data row4 col1" >90</td>
#       <td id="T_046a3_row4_col2" class="data row4 col2" >85</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_046a3_row5_col0" class="data row5 col0" >88</td>
#       <td id="T_046a3_row5_col1" class="data row5 col1" >95</td>
#       <td id="T_046a3_row5_col2" class="data row5 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_046a3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_046a3_row6_col0" class="data row6 col0" >90</td>
#       <td id="T_046a3_row6_col1" class="data row6 col1" >82</td>
#       <td id="T_046a3_row6_col2" class="data row6 col2" >88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Clear Style

# %%
styled_df = df.style.background_gradient()
styled_df.clear()
styled_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_28167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28167_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_28167_level0_col1" class="col_heading level0 col1" >Grade_Semester1</th>
#       <th id="T_28167_level0_col2" class="col_heading level0 col2" >Grade_Semester2</th>
#       <th id="T_28167_level0_col3" class="col_heading level0 col3" >Grade_Semester3</th>
#       <th id="T_28167_level0_col4" class="col_heading level0 col4" >Tuition_Fees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28167_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28167_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_28167_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_28167_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_28167_row0_col3" class="data row0 col3" >95</td>
#       <td id="T_28167_row0_col4" class="data row0 col4" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28167_row1_col0" class="data row1 col0" >Emma</td>
#       <td id="T_28167_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_28167_row1_col2" class="data row1 col2" >92</td>
#       <td id="T_28167_row1_col3" class="data row1 col3" >90</td>
#       <td id="T_28167_row1_col4" class="data row1 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28167_row2_col0" class="data row2 col0" >Michael</td>
#       <td id="T_28167_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_28167_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_28167_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_28167_row2_col4" class="data row2 col4" >6000</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28167_row3_col0" class="data row3 col0" >Sophia</td>
#       <td id="T_28167_row3_col1" class="data row3 col1" >92</td>
#       <td id="T_28167_row3_col2" class="data row3 col2" >85</td>
#       <td id="T_28167_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_28167_row3_col4" class="data row3 col4" >6500</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28167_row4_col0" class="data row4 col0" >William</td>
#       <td id="T_28167_row4_col1" class="data row4 col1" >78</td>
#       <td id="T_28167_row4_col2" class="data row4 col2" >90</td>
#       <td id="T_28167_row4_col3" class="data row4 col3" >85</td>
#       <td id="T_28167_row4_col4" class="data row4 col4" >7000</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28167_row5_col0" class="data row5 col0" >Olivia</td>
#       <td id="T_28167_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_28167_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_28167_row5_col3" class="data row5 col3" >90</td>
#       <td id="T_28167_row5_col4" class="data row5 col4" >5500</td>
#     </tr>
#     <tr>
#       <th id="T_28167_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28167_row6_col0" class="data row6 col0" >James</td>
#       <td id="T_28167_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_28167_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_28167_row6_col3" class="data row6 col3" >88</td>
#       <td id="T_28167_row6_col4" class="data row6 col4" >6000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Export as Excel File

# %% [markdown]
# ```python
# #Export to Excel
# df.style.to_excel('grades.xlsx')
#
# # Using the specified engine, openpyxl provides better compatibility with styles
# df.style.to_excel('grades.xlsx', engine = 'openpyxl')
#
# # Specify the sheet name
# dfs.to_excel('grades.xlsx', sheet_name = 'Sheet1')
#
# # Specify missing value representation
# dfs.to_excel('grades.xlsx', na_rep='-')
#
# # Floating point number format, the following example converts 0.1234 to 0.12
# dfs.to_excel('grades.xlsx', float_format = "%.2f")
#
# # Include only these two columns
# dfs.to_excel('grades.xlsx', columns = ['Q1', 'Q2'])
#
# # Exclude the header
# dfs.to_excel('grades.xlsx', header = False)
#
# # Exclude the index
# dfs.to_excel('grades.xlsx', index = False)
#
# # Specify the index label, multiple labels for multi-level index
# dfs.to_excel('grades.xlsx', index_label = ['team', 'name'])
#
# # Specify the starting row and starting column
# dfs.to_excel('grades.xlsx', startrow = 10, startcol = 3)
#
# # Do not merge cells
# dfs.to_excel('grades.xlsx', merge_cells = False)
#
# # Specify the encoding
# dfs.to_excel('grades.xlsx', encoding = 'utf-8')
#
# # Infinity representation (Excel does not have a native representation for infinity)
# dfs.to_excel('grades.xlsx', inf_rep = 'inf')
#
# # Display more information in the error log
# dfs.to_excel('grades.xlsx', verbose = True)
#
# #Specify the bottom row and right column to freeze
# dfs.to_excel('grades.xlsx', freeze_panes = (0,2))
# ```
